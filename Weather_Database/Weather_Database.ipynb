# %%
# Import the dependencies
import pandas as pd
import numpy as np
import requests
from citipy import citipy
import time

# Import the API key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 744

# %%
# starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning of the logging")
print("------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i%50 == 0 and i>=50):
        set_count += 1 
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON file and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                           "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_weather_description})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning of the logging
# ------------------------
# Processing Record 1 of Set 1 | padang
# Processing Record 2 of Set 1 | pravia
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | aklavik
# Processing Record 5 of Set 1 | paka
# Processing Record 6 of Set 1 | peniche
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | henties bay
# Processing Record 12 of Set 1 | pravda
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | verkhneye dubrovo
# Processing Record 15 of Set 1 | husavik
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | snasa
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | kharp
# Processing Record 21 of Set 1 | thinadhoo
# Processing Record 22 of Set 1 | fort frances
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | eydhafushi
# Processing Record 27 of Set 1 | tuatapere
# Processing Record 28 of Set 1 | makung
# City not found. Skipping...
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | barrhead
# Processing Record 31 of Set 1 | wagar
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | arvika
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | pandan
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 1 | la asuncion
# Processing Record 39 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 1 | san anselmo
# Processing Record 41 of Set 1 | dubti
# Processing Record 42 of Set 1 | mairana
# Processing Record 43 of Set 1 | ajdabiya
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | paramonga
# Processing Record 47 of Set 1 | djenne
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | umred
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | banjar
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | santa isabel do rio negro
# Processing Record 5 of Set 2 | fushan
# Processing Record 6 of Set 2 | constitucion
# Processing Record 7 of Set 2 | nome
# Processing Record 8 of Set 2 | severo-kurilsk
# Processing Record 9 of Set 2 | bilma
# Processing Record 10 of Set 2 | otukpo
# Processing Record 11 of Set 2 | margate
# Processing Record 12 of Set 2 | lompoc
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | lulea
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | longyearbyen
# Processing Record 20 of Set 2 | champerico
# Processing Record 21 of Set 2 | waipawa
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | sol-iletsk
# Processing Record 24 of Set 2 | klaksvik
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | luderitz
# Processing Record 27 of Set 2 | micomeseng
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | zhigansk
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | hamilton
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | sao luiz gonzaga
# Processing Record 38 of Set 2 | nuevo progreso
# Processing Record 39 of Set 2 | geraldton
# Processing Record 40 of Set 2 | ribeira grande
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 2 | eureka
# Processing Record 46 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 2 | coracora
# Processing Record 48 of Set 2 | hami
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | conceicao do araguaia
# Processing Record 1 of Set 3 | mogadishu
# Processing Record 2 of Set 3 | acarau
# Processing Record 3 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 3 | foumban
# Processing Record 5 of Set 3 | byron bay
# Processing Record 6 of Set 3 | black river
# Processing Record 7 of Set 3 | san quintin
# Processing Record 8 of Set 3 | gillette
# Processing Record 9 of Set 3 | jagdalpur
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | maniitsoq
# Processing Record 12 of Set 3 | meulaboh
# Processing Record 13 of Set 3 | sitka
# Processing Record 14 of Set 3 | alyangula
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | harrismith
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | atar
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | ahipara
# Processing Record 21 of Set 3 | tateyama
# Processing Record 22 of Set 3 | kilkenny
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | gimli
# Processing Record 25 of Set 3 | yumen
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | tongzi
# Processing Record 29 of Set 3 | troitsk
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | tokur
# Processing Record 32 of Set 3 | cabo san lucas
# Processing Record 33 of Set 3 | kununurra
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | raga
# Processing Record 36 of Set 3 | acajutla
# Processing Record 37 of Set 3 | hilo
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | aripuana
# Processing Record 40 of Set 3 | westport
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | saquena
# Processing Record 43 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 3 | yulara
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | bluff
# Processing Record 48 of Set 3 | gizo
# Processing Record 49 of Set 3 | butaritari
# Processing Record 50 of Set 3 | beloha
# Processing Record 1 of Set 4 | japura
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | marang
# Processing Record 5 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 4 | mugur-aksy
# Processing Record 7 of Set 4 | callaguip
# Processing Record 8 of Set 4 | brokopondo
# Processing Record 9 of Set 4 | salekhard
# Processing Record 10 of Set 4 | borogontsy
# Processing Record 11 of Set 4 | sinnamary
# Processing Record 12 of Set 4 | portland
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | kozulka
# Processing Record 15 of Set 4 | brae
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | yining
# Processing Record 18 of Set 4 | segezha
# Processing Record 19 of Set 4 | isla vista
# Processing Record 20 of Set 4 | pacific grove
# Processing Record 21 of Set 4 | carnarvon
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | marienburg
# Processing Record 25 of Set 4 | doha
# Processing Record 26 of Set 4 | port macquarie
# Processing Record 27 of Set 4 | port lincoln
# Processing Record 28 of Set 4 | nchelenge
# Processing Record 29 of Set 4 | marv dasht
# City not found. Skipping...
# Processing Record 30 of Set 4 | tautira
# Processing Record 31 of Set 4 | broome
# Processing Record 32 of Set 4 | alexander city
# Processing Record 33 of Set 4 | aguimes
# Processing Record 34 of Set 4 | vestmanna
# Processing Record 35 of Set 4 | jega
# Processing Record 36 of Set 4 | victoria
# Processing Record 37 of Set 4 | belmonte
# Processing Record 38 of Set 4 | te anau
# Processing Record 39 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 4 | swinoujscie
# Processing Record 41 of Set 4 | kaabong
# Processing Record 42 of Set 4 | pocatello
# Processing Record 43 of Set 4 | hofn
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | xuanhua
# Processing Record 46 of Set 4 | sao gabriel da cachoeira
# Processing Record 47 of Set 4 | atikokan
# Processing Record 48 of Set 4 | lexington park
# Processing Record 49 of Set 4 | ouesso
# Processing Record 50 of Set 4 | galesong
# Processing Record 1 of Set 5 | sosnovo-ozerskoye
# Processing Record 2 of Set 5 | marsh harbour
# Processing Record 3 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 5 | upata
# Processing Record 6 of Set 5 | fengcheng
# Processing Record 7 of Set 5 | lazaro cardenas
# Processing Record 8 of Set 5 | san julian
# Processing Record 9 of Set 5 | tome-acu
# City not found. Skipping...
# Processing Record 10 of Set 5 | hasaki
# Processing Record 11 of Set 5 | luorong
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | avarua
# Processing Record 14 of Set 5 | dikson
# Processing Record 15 of Set 5 | gorin
# Processing Record 16 of Set 5 | coquimbo
# Processing Record 17 of Set 5 | un
# City not found. Skipping...
# Processing Record 18 of Set 5 | zaysan
# Processing Record 19 of Set 5 | alexandria
# Processing Record 20 of Set 5 | tecoanapa
# Processing Record 21 of Set 5 | moose factory
# Processing Record 22 of Set 5 | fruitvale
# Processing Record 23 of Set 5 | provideniya
# Processing Record 24 of Set 5 | moron
# Processing Record 25 of Set 5 | san patricio
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | gornopravdinsk
# Processing Record 28 of Set 5 | kanigoro
# Processing Record 29 of Set 5 | harper
# Processing Record 30 of Set 5 | muros
# Processing Record 31 of Set 5 | vizinga
# Processing Record 32 of Set 5 | yangjiang
# Processing Record 33 of Set 5 | shangqiu
# Processing Record 34 of Set 5 | muravlenko
# Processing Record 35 of Set 5 | marsabit
# Processing Record 36 of Set 5 | piryion
# City not found. Skipping...
# Processing Record 37 of Set 5 | praia
# Processing Record 38 of Set 5 | kangaba
# Processing Record 39 of Set 5 | fukue
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | maun
# Processing Record 42 of Set 5 | talnakh
# Processing Record 43 of Set 5 | tuktoyaktuk
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | vostok
# Processing Record 46 of Set 5 | balkhash
# Processing Record 47 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 48 of Set 5 | saint-joseph
# Processing Record 49 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 5 | faya
# Processing Record 1 of Set 6 | latung
# Processing Record 2 of Set 6 | bardiyah
# Processing Record 3 of Set 6 | airai
# Processing Record 4 of Set 6 | christiansburg
# Processing Record 5 of Set 6 | clyde river
# Processing Record 6 of Set 6 | balabac
# Processing Record 7 of Set 6 | havre-saint-pierre
# Processing Record 8 of Set 6 | manavgat
# Processing Record 9 of Set 6 | burgersdorp
# Processing Record 10 of Set 6 | beringovskiy
# Processing Record 11 of Set 6 | vila franca do campo
# Processing Record 12 of Set 6 | ekuvukeni
# Processing Record 13 of Set 6 | mulbagal
# Processing Record 14 of Set 6 | korfovskiy
# Processing Record 15 of Set 6 | san jose
# Processing Record 16 of Set 6 | anaco
# Processing Record 17 of Set 6 | ikom
# Processing Record 18 of Set 6 | kirakira
# Processing Record 19 of Set 6 | waitati
# Processing Record 20 of Set 6 | nouadhibou
# Processing Record 21 of Set 6 | tasiilaq
# Processing Record 22 of Set 6 | olafsvik
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | kjopsvik
# Processing Record 25 of Set 6 | salalah
# Processing Record 26 of Set 6 | kisangani
# Processing Record 27 of Set 6 | comodoro rivadavia
# Processing Record 28 of Set 6 | san andres
# Processing Record 29 of Set 6 | kudahuvadhoo
# Processing Record 30 of Set 6 | the valley
# Processing Record 31 of Set 6 | nanpiao
# Processing Record 32 of Set 6 | cayenne
# Processing Record 33 of Set 6 | simoes
# Processing Record 34 of Set 6 | richards bay
# Processing Record 35 of Set 6 | plettenberg bay
# Processing Record 36 of Set 6 | vutcani
# Processing Record 37 of Set 6 | bandarbeyla
# Processing Record 38 of Set 6 | hovd
# Processing Record 39 of Set 6 | tura
# Processing Record 40 of Set 6 | morant bay
# Processing Record 41 of Set 6 | narsaq
# Processing Record 42 of Set 6 | bud
# Processing Record 43 of Set 6 | bilibino
# Processing Record 44 of Set 6 | tamandare
# Processing Record 45 of Set 6 | riberalta
# Processing Record 46 of Set 6 | marzuq
# Processing Record 47 of Set 6 | dhidhdhoo
# Processing Record 48 of Set 6 | zhiryatino
# Processing Record 49 of Set 6 | biak
# Processing Record 50 of Set 6 | bengkulu
# Processing Record 1 of Set 7 | omboue
# Processing Record 2 of Set 7 | taoudenni
# Processing Record 3 of Set 7 | lerwick
# Processing Record 4 of Set 7 | eyl
# Processing Record 5 of Set 7 | ust-maya
# Processing Record 6 of Set 7 | mount isa
# Processing Record 7 of Set 7 | cherskiy
# Processing Record 8 of Set 7 | fasa
# Processing Record 9 of Set 7 | san cristobal
# Processing Record 10 of Set 7 | batagay-alyta
# Processing Record 11 of Set 7 | cabedelo
# Processing Record 12 of Set 7 | diapaga
# Processing Record 13 of Set 7 | santa maria del oro
# Processing Record 14 of Set 7 | tongren
# Processing Record 15 of Set 7 | pudozh
# Processing Record 16 of Set 7 | bemidji
# Processing Record 17 of Set 7 | norman wells
# Processing Record 18 of Set 7 | kuytun
# Processing Record 19 of Set 7 | camacha
# Processing Record 20 of Set 7 | mahon
# Processing Record 21 of Set 7 | caravelas
# Processing Record 22 of Set 7 | waitara
# Processing Record 23 of Set 7 | ancud
# Processing Record 24 of Set 7 | miri
# Processing Record 25 of Set 7 | samarai
# Processing Record 26 of Set 7 | bhatkal
# Processing Record 27 of Set 7 | lasa
# Processing Record 28 of Set 7 | derzhavinsk
# Processing Record 29 of Set 7 | baillif
# Processing Record 30 of Set 7 | saldanha
# Processing Record 31 of Set 7 | lagoa
# Processing Record 32 of Set 7 | staryy nadym
# Processing Record 33 of Set 7 | port hardy
# Processing Record 34 of Set 7 | kahului
# Processing Record 35 of Set 7 | scharnstein
# Processing Record 36 of Set 7 | barranca
# Processing Record 37 of Set 7 | omsukchan
# Processing Record 38 of Set 7 | abu zabad
# Processing Record 39 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 7 | tessalit
# Processing Record 41 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 7 | manokwari
# Processing Record 43 of Set 7 | ambilobe
# Processing Record 44 of Set 7 | norfolk
# Processing Record 45 of Set 7 | nara
# Processing Record 46 of Set 7 | olean
# Processing Record 47 of Set 7 | half moon bay
# Processing Record 48 of Set 7 | salsomaggiore terme
# Processing Record 49 of Set 7 | la ronge
# Processing Record 50 of Set 7 | kawalu
# Processing Record 1 of Set 8 | kihei
# Processing Record 2 of Set 8 | yarkovo
# Processing Record 3 of Set 8 | grand gaube
# Processing Record 4 of Set 8 | banda aceh
# Processing Record 5 of Set 8 | necochea
# Processing Record 6 of Set 8 | dutlwe
# Processing Record 7 of Set 8 | evensk
# Processing Record 8 of Set 8 | zambezi
# Processing Record 9 of Set 8 | tadine
# Processing Record 10 of Set 8 | chapais
# Processing Record 11 of Set 8 | souillac
# Processing Record 12 of Set 8 | denpasar
# Processing Record 13 of Set 8 | trudarmeyskiy
# Processing Record 14 of Set 8 | merritt island
# Processing Record 15 of Set 8 | pingliang
# Processing Record 16 of Set 8 | oranjestad
# Processing Record 17 of Set 8 | bethel
# Processing Record 18 of Set 8 | taltal
# Processing Record 19 of Set 8 | ilo
# Processing Record 20 of Set 8 | midleton
# Processing Record 21 of Set 8 | dingle
# Processing Record 22 of Set 8 | bataipora
# Processing Record 23 of Set 8 | guerrero negro
# Processing Record 24 of Set 8 | kattivakkam
# Processing Record 25 of Set 8 | garowe
# Processing Record 26 of Set 8 | kruisfontein
# Processing Record 27 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 8 | labrea
# Processing Record 29 of Set 8 | baghdad
# Processing Record 30 of Set 8 | tefe
# Processing Record 31 of Set 8 | idritsa
# Processing Record 32 of Set 8 | cine
# Processing Record 33 of Set 8 | cap malheureux
# Processing Record 34 of Set 8 | mehamn
# Processing Record 35 of Set 8 | rach gia
# Processing Record 36 of Set 8 | labuhan
# Processing Record 37 of Set 8 | baykit
# Processing Record 38 of Set 8 | fallon
# Processing Record 39 of Set 8 | fuerte olimpo
# Processing Record 40 of Set 8 | nanortalik
# Processing Record 41 of Set 8 | marawi
# Processing Record 42 of Set 8 | rawson
# Processing Record 43 of Set 8 | matara
# Processing Record 44 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 45 of Set 8 | xiaoshi
# Processing Record 46 of Set 8 | ende
# Processing Record 47 of Set 8 | guanaja
# Processing Record 48 of Set 8 | leshukonskoye
# Processing Record 49 of Set 8 | hobyo
# Processing Record 50 of Set 8 | presidencia roque saenz pena
# Processing Record 1 of Set 9 | sosnogorsk
# Processing Record 2 of Set 9 | ugoofaaru
# Processing Record 3 of Set 9 | tayu
# Processing Record 4 of Set 9 | fairbanks
# Processing Record 5 of Set 9 | mayumba
# Processing Record 6 of Set 9 | meadow lake
# Processing Record 7 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 9 | seinajoki
# Processing Record 9 of Set 9 | igarka
# Processing Record 10 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 9 | ambunti
# Processing Record 12 of Set 9 | aneho
# Processing Record 13 of Set 9 | corumba
# Processing Record 14 of Set 9 | keflavik
# Processing Record 15 of Set 9 | iberia
# Processing Record 16 of Set 9 | scarborough
# Processing Record 17 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 9 | kieta
# Processing Record 19 of Set 9 | manacapuru
# Processing Record 20 of Set 9 | honiara
# Processing Record 21 of Set 9 | zeya
# Processing Record 22 of Set 9 | chuy
# Processing Record 23 of Set 9 | alugan
# Processing Record 24 of Set 9 | mersing
# Processing Record 25 of Set 9 | canoinhas
# Processing Record 26 of Set 9 | okhotsk
# Processing Record 27 of Set 9 | kamaishi
# Processing Record 28 of Set 9 | calvinia
# Processing Record 29 of Set 9 | semnan
# Processing Record 30 of Set 9 | aljezur
# Processing Record 31 of Set 9 | itoman
# Processing Record 32 of Set 9 | moa
# Processing Record 33 of Set 9 | kargasok
# Processing Record 34 of Set 9 | nador
# Processing Record 35 of Set 9 | lorengau
# Processing Record 36 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 9 | cam ranh
# Processing Record 38 of Set 9 | constantine
# Processing Record 39 of Set 9 | laguna
# Processing Record 40 of Set 9 | ahuimanu
# Processing Record 41 of Set 9 | saint-georges
# Processing Record 42 of Set 9 | mumford
# Processing Record 43 of Set 9 | karratha
# Processing Record 44 of Set 9 | traverse city
# Processing Record 45 of Set 9 | torquay
# Processing Record 46 of Set 9 | papasquiaro
# City not found. Skipping...
# Processing Record 47 of Set 9 | saint-augustin
# Processing Record 48 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 9 | coihaique
# Processing Record 50 of Set 9 | nizhniy kuranakh
# Processing Record 1 of Set 10 | vanderhoof
# Processing Record 2 of Set 10 | caetite
# Processing Record 3 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 10 | lexington
# Processing Record 5 of Set 10 | tynda
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | sharon
# Processing Record 8 of Set 10 | trat
# Processing Record 9 of Set 10 | altay
# Processing Record 10 of Set 10 | kovdor
# Processing Record 11 of Set 10 | voh
# Processing Record 12 of Set 10 | kamenka
# Processing Record 13 of Set 10 | dunfermline
# Processing Record 14 of Set 10 | bam
# Processing Record 15 of Set 10 | tornio
# Processing Record 16 of Set 10 | cradock
# Processing Record 17 of Set 10 | sambava
# Processing Record 18 of Set 10 | saint-louis
# Processing Record 19 of Set 10 | palmer
# Processing Record 20 of Set 10 | bundaberg
# Processing Record 21 of Set 10 | haines junction
# Processing Record 22 of Set 10 | deputatskiy
# Processing Record 23 of Set 10 | punto fijo
# Processing Record 24 of Set 10 | mvuma
# Processing Record 25 of Set 10 | pundaguitan
# Processing Record 26 of Set 10 | norsup
# Processing Record 27 of Set 10 | elbrus
# Processing Record 28 of Set 10 | vidim
# Processing Record 29 of Set 10 | minab
# Processing Record 30 of Set 10 | seoul
# Processing Record 31 of Set 10 | zhuhai
# Processing Record 32 of Set 10 | lerik
# Processing Record 33 of Set 10 | sioux lookout
# Processing Record 34 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 10 | grenaa
# Processing Record 36 of Set 10 | den helder
# Processing Record 37 of Set 10 | wattegama
# Processing Record 38 of Set 10 | estelle
# Processing Record 39 of Set 10 | ilulissat
# Processing Record 40 of Set 10 | itaqui
# Processing Record 41 of Set 10 | morondava
# Processing Record 42 of Set 10 | vestmannaeyjar
# Processing Record 43 of Set 10 | cacahoatan
# Processing Record 44 of Set 10 | antequera
# Processing Record 45 of Set 10 | patitirion
# Processing Record 46 of Set 10 | carira
# Processing Record 47 of Set 10 | jacareacanga
# Processing Record 48 of Set 10 | santa cruz
# Processing Record 49 of Set 10 | port shepstone
# Processing Record 50 of Set 10 | haapiti
# Processing Record 1 of Set 11 | vila
# Processing Record 2 of Set 11 | esfarayen
# Processing Record 3 of Set 11 | leh
# Processing Record 4 of Set 11 | tebingtinggi
# Processing Record 5 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 11 | nola
# Processing Record 7 of Set 11 | inhambane
# Processing Record 8 of Set 11 | qandala
# Processing Record 9 of Set 11 | ajaccio
# Processing Record 10 of Set 11 | ixtapa
# Processing Record 11 of Set 11 | seoni
# Processing Record 12 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 11 | otane
# Processing Record 14 of Set 11 | bucerias
# Processing Record 15 of Set 11 | penukonda
# Processing Record 16 of Set 11 | primorsk
# Processing Record 17 of Set 11 | deniliquin
# Processing Record 18 of Set 11 | linhares
# Processing Record 19 of Set 11 | grindavik
# Processing Record 20 of Set 11 | ostrovnoy
# Processing Record 21 of Set 11 | miramar
# Processing Record 22 of Set 11 | kresttsy
# Processing Record 23 of Set 11 | bodden town
# Processing Record 24 of Set 11 | moussoro
# Processing Record 25 of Set 11 | temiscaming
# Processing Record 26 of Set 11 | yuli
# Processing Record 27 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 28 of Set 11 | ambulu
# Processing Record 29 of Set 11 | vicuna
# Processing Record 30 of Set 11 | havoysund
# Processing Record 31 of Set 11 | camapua
# Processing Record 32 of Set 11 | soma
# Processing Record 33 of Set 11 | san francisco
# Processing Record 34 of Set 11 | magadan
# Processing Record 35 of Set 11 | ruteng
# Processing Record 36 of Set 11 | peleduy
# Processing Record 37 of Set 11 | ribnitz-damgarten
# Processing Record 38 of Set 11 | asau
# Processing Record 39 of Set 11 | erdenet
# Processing Record 40 of Set 11 | isla mujeres
# Processing Record 41 of Set 11 | tual
# Processing Record 42 of Set 11 | mabaruma
# Processing Record 43 of Set 11 | pangnirtung
# Processing Record 44 of Set 11 | bara
# Processing Record 45 of Set 11 | san vicente
# Processing Record 46 of Set 11 | roald
# Processing Record 47 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 48 of Set 11 | tambopata
# Processing Record 49 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 11 | mount gambier
# Processing Record 1 of Set 12 | fortuna
# Processing Record 2 of Set 12 | baoshan
# Processing Record 3 of Set 12 | fuzhou
# Processing Record 4 of Set 12 | college
# Processing Record 5 of Set 12 | ust-koksa
# Processing Record 6 of Set 12 | san isidro
# Processing Record 7 of Set 12 | acari
# Processing Record 8 of Set 12 | kloulklubed
# Processing Record 9 of Set 12 | marsa matruh
# Processing Record 10 of Set 12 | krk
# Processing Record 11 of Set 12 | tarbes
# Processing Record 12 of Set 12 | lesosibirsk
# Processing Record 13 of Set 12 | waingapu
# Processing Record 14 of Set 12 | nizhnyaya poyma
# Processing Record 15 of Set 12 | ron
# Processing Record 16 of Set 12 | cabadiangan
# Processing Record 17 of Set 12 | ternova
# Processing Record 18 of Set 12 | nogent-le-rotrou
# Processing Record 19 of Set 12 | sundsvall
# Processing Record 20 of Set 12 | akyab
# Processing Record 21 of Set 12 | mangochi
# Processing Record 22 of Set 12 | lusambo
# Processing Record 23 of Set 12 | teahupoo
# Processing Record 24 of Set 12 | aginskoye
# Processing Record 25 of Set 12 | manta
# Processing Record 26 of Set 12 | santa maria
# Processing Record 27 of Set 12 | sorland
# Processing Record 28 of Set 12 | praia da vitoria
# Processing Record 29 of Set 12 | naze
# Processing Record 30 of Set 12 | akhaldaba
# Processing Record 31 of Set 12 | beeville
# Processing Record 32 of Set 12 | tanete
# Processing Record 33 of Set 12 | west bay
# Processing Record 34 of Set 12 | adrar
# Processing Record 35 of Set 12 | kangaatsiaq
# Processing Record 36 of Set 12 | hualmay
# Processing Record 37 of Set 12 | chicama
# Processing Record 38 of Set 12 | grand baie
# Processing Record 39 of Set 12 | paarl
# Processing Record 40 of Set 12 | hambantota
# Processing Record 41 of Set 12 | nokaneng
# Processing Record 42 of Set 12 | saint-pierre
# Processing Record 43 of Set 12 | freeport
# Processing Record 44 of Set 12 | khandyga
# Processing Record 45 of Set 12 | los llanos de aridane
# Processing Record 46 of Set 12 | pahrump
# Processing Record 47 of Set 12 | sao joao de pirabas
# Processing Record 48 of Set 12 | atbasar
# Processing Record 49 of Set 12 | ocos
# Processing Record 50 of Set 12 | nhulunbuy
# Processing Record 1 of Set 13 | bathsheba
# Processing Record 2 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 3 of Set 13 | blind river
# Processing Record 4 of Set 13 | trairi
# Processing Record 5 of Set 13 | lavrentiya
# Processing Record 6 of Set 13 | siyabuswa
# Processing Record 7 of Set 13 | walvis bay
# Processing Record 8 of Set 13 | betsiamites
# Processing Record 9 of Set 13 | russell
# Processing Record 10 of Set 13 | tommot
# Processing Record 11 of Set 13 | samarinda
# Processing Record 12 of Set 13 | obidos
# Processing Record 13 of Set 13 | bom jesus da lapa
# Processing Record 14 of Set 13 | huron
# Processing Record 15 of Set 13 | plymouth
# Processing Record 16 of Set 13 | port hedland
# Processing Record 17 of Set 13 | lastoursville
# Processing Record 18 of Set 13 | laiagam
# City not found. Skipping...
# Processing Record 19 of Set 13 | turtas
# Processing Record 20 of Set 13 | celestun
# Processing Record 21 of Set 13 | berlevag
# Processing Record 22 of Set 13 | wapi pathum
# Processing Record 23 of Set 13 | srednekolymsk
# Processing Record 24 of Set 13 | hervey bay
# Processing Record 25 of Set 13 | mitzic
# Processing Record 26 of Set 13 | altamira
# Processing Record 27 of Set 13 | lubango
# Processing Record 28 of Set 13 | bekhteyevka
# Processing Record 29 of Set 13 | korba
# Processing Record 30 of Set 13 | alice springs
# Processing Record 31 of Set 13 | anchorage
# Processing Record 32 of Set 13 | yenagoa
# Processing Record 33 of Set 13 | dunedin
# Processing Record 34 of Set 13 | puerto baquerizo moreno
# Processing Record 35 of Set 13 | bonavista
# Processing Record 36 of Set 13 | reserva
# Processing Record 37 of Set 13 | calabozo
# Processing Record 38 of Set 13 | volkach
# Processing Record 39 of Set 13 | lincoln
# Processing Record 40 of Set 13 | kilindoni
# Processing Record 41 of Set 13 | sajanan
# Processing Record 42 of Set 13 | muncar
# Processing Record 43 of Set 13 | san policarpo
# Processing Record 44 of Set 13 | santander
# Processing Record 45 of Set 13 | bunia
# Processing Record 46 of Set 13 | noumea
# Processing Record 47 of Set 13 | claremore
# Processing Record 48 of Set 13 | luganville
# Processing Record 49 of Set 13 | teguldet
# Processing Record 50 of Set 13 | danville
# Processing Record 1 of Set 14 | clearwater
# Processing Record 2 of Set 14 | bereda
# Processing Record 3 of Set 14 | flagstaff
# Processing Record 4 of Set 14 | sandwick
# Processing Record 5 of Set 14 | tilichiki
# Processing Record 6 of Set 14 | vardo
# Processing Record 7 of Set 14 | mahajanga
# Processing Record 8 of Set 14 | gazanjyk
# Processing Record 9 of Set 14 | isangel
# Processing Record 10 of Set 14 | san juan
# Processing Record 11 of Set 14 | amparai
# City not found. Skipping...
# Processing Record 12 of Set 14 | sindor
# Processing Record 13 of Set 14 | popondetta
# Processing Record 14 of Set 14 | nieuwerkerken
# Processing Record 15 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 14 | bukama
# Processing Record 17 of Set 14 | urumqi
# Processing Record 18 of Set 14 | kasempa
# Processing Record 19 of Set 14 | buraydah
# Processing Record 20 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 21 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 14 | huarmey
# Processing Record 23 of Set 14 | carbonia
# Processing Record 24 of Set 14 | komsomolskiy
# Processing Record 25 of Set 14 | soto la marina
# Processing Record 26 of Set 14 | oulainen
# Processing Record 27 of Set 14 | cravo norte
# Processing Record 28 of Set 14 | progreso
# Processing Record 29 of Set 14 | snyder
# Processing Record 30 of Set 14 | muroto
# Processing Record 31 of Set 14 | ilanskiy
# Processing Record 32 of Set 14 | stromness
# Processing Record 33 of Set 14 | winnemucca
# Processing Record 34 of Set 14 | askino
# Processing Record 35 of Set 14 | vrangel
# Processing Record 36 of Set 14 | tigil
# Processing Record 37 of Set 14 | boende
# Processing Record 38 of Set 14 | lollar
# Processing Record 39 of Set 14 | kincardine
# Processing Record 40 of Set 14 | baturaja
# Processing Record 41 of Set 14 | maneadero
# Processing Record 42 of Set 14 | riyadh
# Processing Record 43 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 14 | hirado
# Processing Record 45 of Set 14 | verkhnyaya inta
# Processing Record 46 of Set 14 | clarence town
# Processing Record 47 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 48 of Set 14 | chara
# Processing Record 49 of Set 14 | endicott
# Processing Record 50 of Set 14 | tibiri
# Processing Record 1 of Set 15 | ozernovskiy
# Processing Record 2 of Set 15 | wanning
# Processing Record 3 of Set 15 | doba
# Processing Record 4 of Set 15 | itacare
# Processing Record 5 of Set 15 | moerai
# Processing Record 6 of Set 15 | kholodnyy
# Processing Record 7 of Set 15 | solnechnyy
# Processing Record 8 of Set 15 | tomatlan
# Processing Record 9 of Set 15 | natal
# Processing Record 10 of Set 15 | lavumisa
# Processing Record 11 of Set 15 | alta floresta
# Processing Record 12 of Set 15 | devils lake
# Processing Record 13 of Set 15 | mana
# Processing Record 14 of Set 15 | yakeshi
# Processing Record 15 of Set 15 | bogorodskoye
# Processing Record 16 of Set 15 | sarai
# Processing Record 17 of Set 15 | yamada
# Processing Record 18 of Set 15 | puerto narino
# Processing Record 19 of Set 15 | masaka
# Processing Record 20 of Set 15 | cururupu
# Processing Record 21 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 15 | takoradi
# Processing Record 23 of Set 15 | anastacio
# Processing Record 24 of Set 15 | oliveira do hospital
# Processing Record 25 of Set 15 | koyilandi
# City not found. Skipping...
# Processing Record 26 of Set 15 | qaqortoq
# Processing Record 27 of Set 15 | turukhansk
# Processing Record 28 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 29 of Set 15 | domoni
# Processing Record 30 of Set 15 | dubbo
# Processing Record 31 of Set 15 | khairpur nathan shah
# Processing Record 32 of Set 15 | vaitape
# Processing Record 33 of Set 15 | bubaque
# Processing Record 34 of Set 15 | humberto de campos
# Processing Record 35 of Set 15 | tarboro
# Processing Record 36 of Set 15 | smithers
# Processing Record 37 of Set 15 | weligama
# Processing Record 38 of Set 15 | kapuskasing
# Processing Record 39 of Set 15 | camana
# Processing Record 40 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 41 of Set 15 | fort abbas
# Processing Record 42 of Set 15 | payette
# Processing Record 43 of Set 15 | wolfsberg
# Processing Record 44 of Set 15 | xichang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Padang  -0.9492  100.3543     77.49        87          99        3.74
# 1   Pravia  43.4906   -6.1508     69.22        88          75        2.30
# 2    Vaini -21.2000 -175.2000     73.56        94          75        8.05
# 3  Aklavik  68.2191 -135.0107     41.00        93         100        3.44
# 4     Paka   4.6374  103.4368     78.73        89         100        0.00
#
#   Country Current Description
# 0      ID     overcast clouds
# 1      ES       broken clouds
# 2      TO       broken clouds
# 3      CA                mist
# 4      MY     overcast clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Country                 object
# Current Description     object
# dtype: object

# %%
# Reorder the columns
city_data_df_new = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"] 
city_data_df = city_data_df[city_data_df_new]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Padang      ID  -0.9492  100.3543     77.49        87          99
# 1      Pravia      ES  43.4906   -6.1508     69.22        88          75
# 2       Vaini      TO -21.2000 -175.2000     73.56        94          75
# 3     Aklavik      CA  68.2191 -135.0107     41.00        93         100
# 4        Paka      MY   4.6374  103.4368     78.73        89         100
# 5     Peniche      PT  39.3558   -9.3811     74.08        92          12
# 6     Rikitea      PF -23.1203 -134.9692     70.68        69           0
# 7       Kapaa      US  22.0752 -159.3190     71.92        97          20
# 8     Iqaluit      CA  63.7506  -68.5145     47.93        66          75
# 9  Chokurdakh      RU  70.6333  147.9167     35.76        95         100
#
#    Wind Speed Current Description
# 0        3.74     overcast clouds
# 1        2.30       broken clouds
# 2        8.05       broken clouds
# 3        3.44                mist
# 4        0.00     overcast clouds
# 5        9.33          few clouds
# 6        8.90           clear sky
# 7        5.75          few clouds
# 8        5.75       broken clouds
# 9        3.65     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the city_data_df into a CSV
city_data_df.to_csv(output_data_file, index_label="City ID")
